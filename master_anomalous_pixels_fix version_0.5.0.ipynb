# %%
## Imports. This contains some imports not required for this notebook. 

import sys
import os
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import pylab                   # Needed to plot histograms.
from astropy.io import fits                    # Need this if you want to use astropy.io io objects.
from astropy.stats import mad_std              # The median absolute deviation, a more robust estimator than std.
from PIL import Image
from scipy.ndimage import gaussian_filter
from scipy import signal

'''Filter out warnings. May or may not need this. But shouldn't hurt to put it in.
This is the "new" code for avoiding warnings-- seems to work better. Copied from an SDSS notebook.'''
import warnings
warnings.filterwarnings('ignore')

sys.path.append(r'C:\Users\owenm\Documents\ASTR 21200 2019\Software\a212pylibs\datapype')

from datafits import DataFits

# %%
# Specify the path to the data directory.
# datapath = '/Users/alex/_observing/24-inch/2018/manual_dark/darks_180420'
datapath = r'C:\Users\owenm\Documents\ASTR 21200 2019\Data\Project\dark'
savepath = r'C:\Users\owenm\Documents\ASTR 21200 2019\Data\BadPixelsFitss'

# %%
## List files in the the data directory.

whichpath = datapath

## For ALL the files in the directory.
# allfiles = [f for f in os.listdir(datapath)]

## Various list comprehensions can pick out files with particular characteristics.
allfiles = [f for f in os.listdir(whichpath) if '.fit' in f and ('bias.' in f) and 'mdark' not in f]

allfiles = sorted(allfiles)       ## This is necessary on my Mac, may not be for others?
for i in range(len(allfiles)):
    print( i, allfiles[i])
# Out:
# 0 dark_190421_AA-001_bias.fit
# 1 dark_190421_AA-002_bias.fit
# 2 dark_190421_AA-003_bias.fit
# 3 dark_190421_AA-004_bias.fit
# 4 dark_190421_AA-005_bias.fit
# 5 dark_190421_AA-006_bias.fit
# 6 dark_190421_AA-007_bias.fit
# 7 dark_190421_AA-008_bias.fit
# 8 dark_190421_AA-009_bias.fit
# 9 dark_190421_AA-010_bias.fit
# 10 dark_190421_AA-011_bias.fit
# 11 dark_190421_AA-012_bias.fit
# 12 dark_190421_AA-013_bias.fit
# 13 dark_190421_AA-014_bias.fit
# 14 dark_190421_AA-015_bias.fit
# 15 dark_190421_AA-016_bias.fit
# 16 dark_190421_AA-017_bias.fit
# 17 dark_190421_AA-018_bias.fit
# 18 dark_190421_AA-019_bias.fit
# 19 dark_190421_AA-020_bias.fit
# 20 dark_190421_AA-021_bias.fit
# 21 dark_190421_AA-022_bias.fit
# 22 dark_190421_AA-023_bias.fit
# 23 dark_190421_AA-024_bias.fit
# 24 dark_190421_AA-025_bias.fit
# 25 dark_190421_AA-026_bias.fit
# 26 dark_190421_AA-027_bias.fit
# 27 dark_190421_AA-028_bias.fit
# 28 dark_190421_AA-029_bias.fit
# 29 dark_190421_AA-030_bias.fit
# 30 dark_190504_AB-001_bias.fit
# 31 dark_190504_AB-002_bias.fit
# 32 dark_190504_AB-003_bias.fit
# 33 dark_190504_AB-004_bias.fit
# 34 dark_190504_AB-005_bias.fit
# 35 dark_190504_AB-006_bias.fit
# 36 dark_190504_AB-007_bias.fit
# 37 dark_190504_AB-008_bias.fit
# 38 dark_190504_AB-009_bias.fit
# 39 dark_190504_AB-010_bias.fit
# 40 dark_190504_AB-011_bias.fit
# 41 dark_190504_AB-012_bias.fit
# 42 dark_190504_AB-013_bias.fit
# 43 dark_190504_AB-014_bias.fit
# 44 dark_190504_AB-015_bias.fit
# 45 dark_190504_AB-016_bias.fit
# 46 dark_190504_AB-017_bias.fit
# 47 dark_190504_AB-018_bias.fit
# 48 dark_190504_AB-019_bias.fit
# 49 dark_190504_AB-020_bias.fit
# 50 dark_190504_AB-021_bias.fit
# 51 dark_190504_AB-022_bias.fit
# 52 dark_190504_AB-023_bias.fit
# 53 dark_190504_AB-024_bias.fit
# 54 dark_190504_AB-025_bias.fit
# 55 dark_190504_AB-026_bias.fit
# 56 dark_190504_AB-027_bias.fit
# 57 dark_190504_AB-028_bias.fit
# 58 dark_190504_AB-029_bias.fit
# 59 dark_190504_AB-030_bias.fit
# 60 dark_190504_AB-031_bias.fit
# 61 dark_190504_AB-032_bias.fit
# 62 dark_190504_AB-033_bias.fit
# 63 dark_190504_AB-034_bias.fit
# 64 dark_190504_AB-035_bias.fit
# 65 dark_190504_AB-036_bias.fit
# 66 dark_190504_AB-037_bias.fit
# 67 dark_190504_AB-038_bias.fit
# 68 dark_190504_AB-039_bias.fit
# 69 dark_190504_AB-040_bias.fit
# 70 dark_190504_AB-041_bias.fit
# 71 dark_190504_AB-042_bias.fit
# 72 dark_190504_AB-043_bias.fit
# 73 dark_190504_AB-044_bias.fit
# 74 dark_190504_AB-045_bias.fit
# 75 dark_190504_AB-046_bias.fit
# 76 dark_190504_AB-047_bias.fit
# 77 dark_190504_AB-048_bias.fit
# 78 dark_190504_AB-049_bias.fit
# 79 dark_190504_AB-050_bias.fit
# 80 dark_190504_AC-001_bias.fit
# 81 dark_190504_AC-002_bias.fit
# 82 dark_190504_AC-003_bias.fit
# 83 dark_190504_AC-004_bias.fit
# 84 dark_190504_AC-005_bias.fit
# 85 dark_190504_AC-006_bias.fit
# 86 dark_190504_AC-007_bias.fit
# 87 dark_190504_AC-008_bias.fit
# 88 dark_190504_AC-009_bias.fit
# 89 dark_190504_AC-010_bias.fit
# 90 dark_190504_AC-011_bias.fit
# 91 dark_190504_AC-012_bias.fit
# 92 dark_190504_AC-013_bias.fit
# 93 dark_190504_AC-014_bias.fit
# 94 dark_190504_AC-015_bias.fit
# 95 dark_190504_AC-016_bias.fit
# 96 dark_190504_AC-017_bias.fit
# 97 dark_190504_AC-018_bias.fit
# 98 dark_190504_AC-019_bias.fit
# 99 dark_190504_AC-020_bias.fit
# 100 dark_190504_AC-021_bias.fit
# 101 dark_190504_AC-022_bias.fit
# 102 dark_190504_AC-023_bias.fit
# 103 dark_190504_AC-024_bias.fit
# 104 dark_190504_AC-025_bias.fit
# 105 dark_190504_AD-001_bias.fit
# 106 dark_190504_AD-002_bias.fit
# 107 dark_190504_AD-003_bias.fit
# 108 dark_190504_AD-004_bias.fit
# 109 dark_190504_AD-005_bias.fit
# 110 dark_190504_AD-006_bias.fit
# 111 dark_190504_AD-007_bias.fit
# 112 dark_190504_AD-008_bias.fit
# 113 dark_190504_AD-009_bias.fit
# 114 dark_190504_AD-010_bias.fit
# 115 dark_190504_AD-011_bias.fit
# 116 dark_190504_AD-012_bias.fit
# 117 dark_190504_AD-013_bias.fit
# 118 dark_190504_AD-014_bias.fit
# 119 dark_190504_AD-015_bias.fit
# 120 dark_190504_AD-016_bias.fit
# 121 dark_190504_AD-017_bias.fit
# 122 dark_190504_AD-018_bias.fit
# 123 dark_190504_AD-019_bias.fit
# 124 dark_190504_AD-020_bias.fit
# 125 dark_190504_AD-021_bias.fit
# 126 dark_190504_AD-022_bias.fit
# 127 dark_190504_AD-023_bias.fit
# 128 dark_190504_AD-024_bias.fit
# 129 dark_190504_AD-025_bias.fit
# 130 dark_190504_AD-026_bias.fit
# 131 dark_190504_AD-027_bias.fit
# 132 dark_190504_AD-028_bias.fit
# 133 dark_190504_AD-029_bias.fit
# 134 dark_190504_AD-030_bias.fit
# 135 dark_190504_AD-031_bias.fit
# 136 dark_190504_AD-032_bias.fit
# 137 dark_190504_AD-033_bias.fit
# 138 dark_190504_AD-034_bias.fit
# 139 dark_190504_AD-035_bias.fit
# 140 dark_190504_AD-036_bias.fit
# 141 dark_190504_AD-037_bias.fit
# 142 dark_190504_AD-038_bias.fit
# 143 dark_190504_AD-039_bias.fit
# 144 dark_190504_AD-040_bias.fit
# 145 dark_190504_AD-041_bias.fit
# 146 dark_190504_AD-042_bias.fit
# 147 dark_190504_AD-043_bias.fit
# 148 dark_190504_AD-044_bias.fit
# 149 dark_190504_AD-045_bias.fit
# 150 dark_190504_AD-046_bias.fit
# 151 dark_190504_AD-047_bias.fit
# 152 dark_190504_AD-048_bias.fit
# 153 dark_190504_AD-049_bias.fit
# 154 dark_190504_AD-050_bias.fit
# 155 dark_190504_AD-051_bias.fit
# 156 dark_190504_AD-052_bias.fit
# 157 dark_190504_AD-053_bias.fit
# 158 dark_190504_AD-054_bias.fit
# 159 dark_190504_AD-055_bias.fit
# 160 dark_190504_AD-056_bias.fit
# 161 dark_190504_AD-057_bias.fit
# 162 dark_190504_AD-058_bias.fit
# 163 dark_190504_AD-059_bias.fit
# 164 dark_190504_AD-060_bias.fit
# 165 dark_190504_AD-061_bias.fit
# 166 dark_190504_AD-062_bias.fit
# 167 dark_190504_AD-063_bias.fit
# 168 dark_190504_AD-064_bias.fit
# 169 dark_190504_AD-065_bias.fit
# 170 dark_190504_AD-066_bias.fit
# 171 dark_190504_AD-067_bias.fit
# 172 dark_190504_AD-068_bias.fit
# 173 dark_190504_AD-069_bias.fit
# 174 dark_190504_AD-070_bias.fit
# 175 dark_190504_AD-071_bias.fit
# 176 dark_190504_AD-072_bias.fit
# 177 dark_190504_AD-073_bias.fit
# 178 dark_190504_AD-074_bias.fit
# 179 dark_190504_AD-075_bias.fit
# 180 dark_190504_AD-076_bias.fit
# 181 dark_190504_AD-077_bias.fit
# 182 dark_190504_AD-078_bias.fit
# 183 dark_190504_AD-079_bias.fit
# 184 dark_190504_AD-080_bias.fit
# 185 dark_190504_AD-081_bias.fit
# 186 dark_190504_AD-082_bias.fit
# 187 dark_190504_AD-083_bias.fit
# 188 dark_190504_AD-084_bias.fit
# 189 dark_190504_AD-085_bias.fit
# 190 dark_190504_AD-086_bias.fit
# 191 dark_190504_AD-087_bias.fit
# 192 dark_190504_AD-088_bias.fit
# 193 dark_190504_AD-089_bias.fit
# 194 dark_190504_AD-090_bias.fit
# 195 dark_190504_AD-091_bias.fit
# 196 dark_190504_AD-092_bias.fit
# 197 dark_190504_AD-093_bias.fit
# 198 dark_190504_AD-094_bias.fit
# 199 dark_190504_AD-095_bias.fit
# 200 dark_190504_AD-096_bias.fit
# 201 dark_190504_AD-098_bias.fit
# 202 dark_190504_AD-099_bias.fit
# 203 dark_190504_AD-100_bias.fit
# 204 dark_190504_AD-101_bias.fit
# 205 dark_190504_AD-102_bias.fit
# 206 dark_190504_AD-103_bias.fit
# 207 dark_190504_AD-104_bias.fit
# 208 dark_190504_AD-105_bias.fit
# 209 dark_190504_AD-106_bias.fit
# 210 dark_190504_AD-107_bias.fit
# 211 dark_190504_AD-108_bias.fit
# 212 dark_190504_AD-109_bias.fit
# 213 dark_190504_AD-110_bias.fit
# 214 dark_190504_AD-111_bias.fit
# 215 dark_190504_AD-112_bias.fit
# 216 dark_190504_AD-113_bias.fit
# 217 dark_190504_AD-114_bias.fit
# 218 dark_190504_AD-115_bias.fit
# 219 dark_190504_AD-116_bias.fit
# 220 dark_190504_AD-117_bias.fit
# 221 dark_190504_AD-118_bias.fit
# 222 dark_190504_AD-119_bias.fit
# 223 dark_190504_AD-120_bias.fit
# 224 dark_190504_AD-121_bias.fit
# 225 dark_190504_AD-122_bias.fit
# 226 dark_190504_AD-123_bias.fit
# 227 dark_190504_AD-124_bias.fit
# 228 dark_190504_AD-125_bias.fit
# 229 dark_190504_AD-126_bias.fit
# 230 dark_190504_AD-127_bias.fit
# 231 dark_190504_AD-128_bias.fit
# 232 dark_190504_AD-129_bias.fit
# 233 dark_190504_AD-130_bias.fit
# 234 dark_190504_AD-131_bias.fit
# 235 dark_190504_AD-132_bias.fit
# 236 dark_190504_AD-133_bias.fit
# 237 dark_190504_AD-134_bias.fit
# 238 dark_190504_AD-135_bias.fit
# 239 dark_190504_AD-136_bias.fit
# 240 dark_190504_AD-137_bias.fit
# 241 dark_190504_AD-138_bias.fit
# 242 dark_190504_AD-139_bias.fit
# 243 dark_190504_AD-140_bias.fit
# 244 dark_190504_AD-141_bias.fit
# 245 dark_190504_AD-142_bias.fit
# 246 dark_190504_AD-143_bias.fit
# 247 dark_190504_AD-144_bias.fit
# 248 dark_190504_AD-145_bias.fit
# 249 dark_190504_AD-146_bias.fit
# 250 dark_190504_AD-147_bias.fit
# 251 dark_190504_AD-148_bias.fit
# 252 dark_190504_AD-149_bias.fit
# 253 dark_190504_AD-150_bias.fit
# 254 dark_190504_AD-151_bias.fit
# 255 dark_190504_AD-152_bias.fit
# 256 dark_190504_AD-153_bias.fit
# 257 dark_190504_AD-157_bias.fit
# 258 dark_190504_AD-158_bias.fit
# 259 dark_190504_AD-159_bias.fit
# 260 dark_190504_AD-160_bias.fit
# 261 dark_190504_AD-161_bias.fit
# 262 dark_190504_AD-162_bias.fit
# 263 dark_190504_AD-163_bias.fit
# 264 dark_190504_AD-164_bias.fit
# 265 dark_190504_AD-165_bias.fit
# 266 dark_190504_AD-166_bias.fit
# 267 dark_190504_AD-167_bias.fit
# 268 dark_190504_AD-168_bias.fit
# 269 dark_190504_AD-169_bias.fit
# 270 dark_190504_AD-170_bias.fit
# 271 dark_190504_AD-171_bias.fit
# 272 dark_190504_AD-172_bias.fit
# 273 dark_190504_AD-173_bias.fit
# 274 dark_190504_AD-174_bias.fit
# 275 dark_190504_AD-175_bias.fit
# 276 dark_190504_AD-176_bias.fit
# 277 dark_190504_AD-177_bias.fit
# 278 dark_190504_AD-178_bias.fit
# 279 dark_190504_AD-179_bias.fit
# 280 dark_190504_AD-180_bias.fit
# 281 dark_190504_AD-181_bias.fit
# 282 dark_190504_AD-182_bias.fit
# 283 dark_190504_AD-183_bias.fit
# 284 dark_190504_AD-184_bias.fit
# 285 dark_190504_AD-185_bias.fit
# 286 dark_190504_AD-186_bias.fit
# 287 dark_190504_AD-187_bias.fit
# 288 dark_190504_AD-188_bias.fit
# 289 dark_190504_AD-189_bias.fit
# 290 dark_190504_AD-190_bias.fit
# 291 dark_190504_AD-191_bias.fit
# 292 dark_190504_AD-192_bias.fit
# 293 dark_190504_AD-193_bias.fit
# 294 dark_190504_AD-194_bias.fit
# 295 dark_190504_AD-195_bias.fit
# 296 dark_190504_AD-196_bias.fit
# 297 dark_190504_AD-197_bias.fit
# 298 dark_190504_AD-198_bias.fit
# 299 dark_190504_AD-199_bias.fit
# 300 dark_190504_AD-200_bias.fit

# %%
## Construct a list of files you wish to view and/or process.

acceptlist = True             # True if you want to accept all the files in allfiles.
contiguous = True             # True if you want to accept a contiguous subset of allfiles.
startfile, endfile = 0,9      # The first and last files in a contiquous subset.
flist = [0,3,4,5,6,7,8]        # An explicit list of the files you want to accept.

if acceptlist == True:
    files = allfiles
    for i in range(len(files)):
        print(i, files[i])
else:
    if contiguous == True:
        files = allfiles[startfile:endfile+1]
        for i in range(len(files)):
            print( i, files[i])
    else:
        files = []
        for i in range(len(flist)):
            files.append(allfiles[flist[i]])
        for i in range(len(files)):
            print( i, flist[i], files[i])
# Out:
# 0 dark_190421_AA-001_bias.fit
# 1 dark_190421_AA-002_bias.fit
# 2 dark_190421_AA-003_bias.fit
# 3 dark_190421_AA-004_bias.fit
# 4 dark_190421_AA-005_bias.fit
# 5 dark_190421_AA-006_bias.fit
# 6 dark_190421_AA-007_bias.fit
# 7 dark_190421_AA-008_bias.fit
# 8 dark_190421_AA-009_bias.fit
# 9 dark_190421_AA-010_bias.fit
# 10 dark_190421_AA-011_bias.fit
# 11 dark_190421_AA-012_bias.fit
# 12 dark_190421_AA-013_bias.fit
# 13 dark_190421_AA-014_bias.fit
# 14 dark_190421_AA-015_bias.fit
# 15 dark_190421_AA-016_bias.fit
# 16 dark_190421_AA-017_bias.fit
# 17 dark_190421_AA-018_bias.fit
# 18 dark_190421_AA-019_bias.fit
# 19 dark_190421_AA-020_bias.fit
# 20 dark_190421_AA-021_bias.fit
# 21 dark_190421_AA-022_bias.fit
# 22 dark_190421_AA-023_bias.fit
# 23 dark_190421_AA-024_bias.fit
# 24 dark_190421_AA-025_bias.fit
# 25 dark_190421_AA-026_bias.fit
# 26 dark_190421_AA-027_bias.fit
# 27 dark_190421_AA-028_bias.fit
# 28 dark_190421_AA-029_bias.fit
# 29 dark_190421_AA-030_bias.fit
# 30 dark_190504_AB-001_bias.fit
# 31 dark_190504_AB-002_bias.fit
# 32 dark_190504_AB-003_bias.fit
# 33 dark_190504_AB-004_bias.fit
# 34 dark_190504_AB-005_bias.fit
# 35 dark_190504_AB-006_bias.fit
# 36 dark_190504_AB-007_bias.fit
# 37 dark_190504_AB-008_bias.fit
# 38 dark_190504_AB-009_bias.fit
# 39 dark_190504_AB-010_bias.fit
# 40 dark_190504_AB-011_bias.fit
# 41 dark_190504_AB-012_bias.fit
# 42 dark_190504_AB-013_bias.fit
# 43 dark_190504_AB-014_bias.fit
# 44 dark_190504_AB-015_bias.fit
# 45 dark_190504_AB-016_bias.fit
# 46 dark_190504_AB-017_bias.fit
# 47 dark_190504_AB-018_bias.fit
# 48 dark_190504_AB-019_bias.fit
# 49 dark_190504_AB-020_bias.fit
# 50 dark_190504_AB-021_bias.fit
# 51 dark_190504_AB-022_bias.fit
# 52 dark_190504_AB-023_bias.fit
# 53 dark_190504_AB-024_bias.fit
# 54 dark_190504_AB-025_bias.fit
# 55 dark_190504_AB-026_bias.fit
# 56 dark_190504_AB-027_bias.fit
# 57 dark_190504_AB-028_bias.fit
# 58 dark_190504_AB-029_bias.fit
# 59 dark_190504_AB-030_bias.fit
# 60 dark_190504_AB-031_bias.fit
# 61 dark_190504_AB-032_bias.fit
# 62 dark_190504_AB-033_bias.fit
# 63 dark_190504_AB-034_bias.fit
# 64 dark_190504_AB-035_bias.fit
# 65 dark_190504_AB-036_bias.fit
# 66 dark_190504_AB-037_bias.fit
# 67 dark_190504_AB-038_bias.fit
# 68 dark_190504_AB-039_bias.fit
# 69 dark_190504_AB-040_bias.fit
# 70 dark_190504_AB-041_bias.fit
# 71 dark_190504_AB-042_bias.fit
# 72 dark_190504_AB-043_bias.fit
# 73 dark_190504_AB-044_bias.fit
# 74 dark_190504_AB-045_bias.fit
# 75 dark_190504_AB-046_bias.fit
# 76 dark_190504_AB-047_bias.fit
# 77 dark_190504_AB-048_bias.fit
# 78 dark_190504_AB-049_bias.fit
# 79 dark_190504_AB-050_bias.fit
# 80 dark_190504_AC-001_bias.fit
# 81 dark_190504_AC-002_bias.fit
# 82 dark_190504_AC-003_bias.fit
# 83 dark_190504_AC-004_bias.fit
# 84 dark_190504_AC-005_bias.fit
# 85 dark_190504_AC-006_bias.fit
# 86 dark_190504_AC-007_bias.fit
# 87 dark_190504_AC-008_bias.fit
# 88 dark_190504_AC-009_bias.fit
# 89 dark_190504_AC-010_bias.fit
# 90 dark_190504_AC-011_bias.fit
# 91 dark_190504_AC-012_bias.fit
# 92 dark_190504_AC-013_bias.fit
# 93 dark_190504_AC-014_bias.fit
# 94 dark_190504_AC-015_bias.fit
# 95 dark_190504_AC-016_bias.fit
# 96 dark_190504_AC-017_bias.fit
# 97 dark_190504_AC-018_bias.fit
# 98 dark_190504_AC-019_bias.fit
# 99 dark_190504_AC-020_bias.fit
# 100 dark_190504_AC-021_bias.fit
# 101 dark_190504_AC-022_bias.fit
# 102 dark_190504_AC-023_bias.fit
# 103 dark_190504_AC-024_bias.fit
# 104 dark_190504_AC-025_bias.fit
# 105 dark_190504_AD-001_bias.fit
# 106 dark_190504_AD-002_bias.fit
# 107 dark_190504_AD-003_bias.fit
# 108 dark_190504_AD-004_bias.fit
# 109 dark_190504_AD-005_bias.fit
# 110 dark_190504_AD-006_bias.fit
# 111 dark_190504_AD-007_bias.fit
# 112 dark_190504_AD-008_bias.fit
# 113 dark_190504_AD-009_bias.fit
# 114 dark_190504_AD-010_bias.fit
# 115 dark_190504_AD-011_bias.fit
# 116 dark_190504_AD-012_bias.fit
# 117 dark_190504_AD-013_bias.fit
# 118 dark_190504_AD-014_bias.fit
# 119 dark_190504_AD-015_bias.fit
# 120 dark_190504_AD-016_bias.fit
# 121 dark_190504_AD-017_bias.fit
# 122 dark_190504_AD-018_bias.fit
# 123 dark_190504_AD-019_bias.fit
# 124 dark_190504_AD-020_bias.fit
# 125 dark_190504_AD-021_bias.fit
# 126 dark_190504_AD-022_bias.fit
# 127 dark_190504_AD-023_bias.fit
# 128 dark_190504_AD-024_bias.fit
# 129 dark_190504_AD-025_bias.fit
# 130 dark_190504_AD-026_bias.fit
# 131 dark_190504_AD-027_bias.fit
# 132 dark_190504_AD-028_bias.fit
# 133 dark_190504_AD-029_bias.fit
# 134 dark_190504_AD-030_bias.fit
# 135 dark_190504_AD-031_bias.fit
# 136 dark_190504_AD-032_bias.fit
# 137 dark_190504_AD-033_bias.fit
# 138 dark_190504_AD-034_bias.fit
# 139 dark_190504_AD-035_bias.fit
# 140 dark_190504_AD-036_bias.fit
# 141 dark_190504_AD-037_bias.fit
# 142 dark_190504_AD-038_bias.fit
# 143 dark_190504_AD-039_bias.fit
# 144 dark_190504_AD-040_bias.fit
# 145 dark_190504_AD-041_bias.fit
# 146 dark_190504_AD-042_bias.fit
# 147 dark_190504_AD-043_bias.fit
# 148 dark_190504_AD-044_bias.fit
# 149 dark_190504_AD-045_bias.fit
# 150 dark_190504_AD-046_bias.fit
# 151 dark_190504_AD-047_bias.fit
# 152 dark_190504_AD-048_bias.fit
# 153 dark_190504_AD-049_bias.fit
# 154 dark_190504_AD-050_bias.fit
# 155 dark_190504_AD-051_bias.fit
# 156 dark_190504_AD-052_bias.fit
# 157 dark_190504_AD-053_bias.fit
# 158 dark_190504_AD-054_bias.fit
# 159 dark_190504_AD-055_bias.fit
# 160 dark_190504_AD-056_bias.fit
# 161 dark_190504_AD-057_bias.fit
# 162 dark_190504_AD-058_bias.fit
# 163 dark_190504_AD-059_bias.fit
# 164 dark_190504_AD-060_bias.fit
# 165 dark_190504_AD-061_bias.fit
# 166 dark_190504_AD-062_bias.fit
# 167 dark_190504_AD-063_bias.fit
# 168 dark_190504_AD-064_bias.fit
# 169 dark_190504_AD-065_bias.fit
# 170 dark_190504_AD-066_bias.fit
# 171 dark_190504_AD-067_bias.fit
# 172 dark_190504_AD-068_bias.fit
# 173 dark_190504_AD-069_bias.fit
# 174 dark_190504_AD-070_bias.fit
# 175 dark_190504_AD-071_bias.fit
# 176 dark_190504_AD-072_bias.fit
# 177 dark_190504_AD-073_bias.fit
# 178 dark_190504_AD-074_bias.fit
# 179 dark_190504_AD-075_bias.fit
# 180 dark_190504_AD-076_bias.fit
# 181 dark_190504_AD-077_bias.fit
# 182 dark_190504_AD-078_bias.fit
# 183 dark_190504_AD-079_bias.fit
# 184 dark_190504_AD-080_bias.fit
# 185 dark_190504_AD-081_bias.fit
# 186 dark_190504_AD-082_bias.fit
# 187 dark_190504_AD-083_bias.fit
# 188 dark_190504_AD-084_bias.fit
# 189 dark_190504_AD-085_bias.fit
# 190 dark_190504_AD-086_bias.fit
# 191 dark_190504_AD-087_bias.fit
# 192 dark_190504_AD-088_bias.fit
# 193 dark_190504_AD-089_bias.fit
# 194 dark_190504_AD-090_bias.fit
# 195 dark_190504_AD-091_bias.fit
# 196 dark_190504_AD-092_bias.fit
# 197 dark_190504_AD-093_bias.fit
# 198 dark_190504_AD-094_bias.fit
# 199 dark_190504_AD-095_bias.fit
# 200 dark_190504_AD-096_bias.fit
# 201 dark_190504_AD-098_bias.fit
# 202 dark_190504_AD-099_bias.fit
# 203 dark_190504_AD-100_bias.fit
# 204 dark_190504_AD-101_bias.fit
# 205 dark_190504_AD-102_bias.fit
# 206 dark_190504_AD-103_bias.fit
# 207 dark_190504_AD-104_bias.fit
# 208 dark_190504_AD-105_bias.fit
# 209 dark_190504_AD-106_bias.fit
# 210 dark_190504_AD-107_bias.fit
# 211 dark_190504_AD-108_bias.fit
# 212 dark_190504_AD-109_bias.fit
# 213 dark_190504_AD-110_bias.fit
# 214 dark_190504_AD-111_bias.fit
# 215 dark_190504_AD-112_bias.fit
# 216 dark_190504_AD-113_bias.fit
# 217 dark_190504_AD-114_bias.fit
# 218 dark_190504_AD-115_bias.fit
# 219 dark_190504_AD-116_bias.fit
# 220 dark_190504_AD-117_bias.fit
# 221 dark_190504_AD-118_bias.fit
# 222 dark_190504_AD-119_bias.fit
# 223 dark_190504_AD-120_bias.fit
# 224 dark_190504_AD-121_bias.fit
# 225 dark_190504_AD-122_bias.fit
# 226 dark_190504_AD-123_bias.fit
# 227 dark_190504_AD-124_bias.fit
# 228 dark_190504_AD-125_bias.fit
# 229 dark_190504_AD-126_bias.fit
# 230 dark_190504_AD-127_bias.fit
# 231 dark_190504_AD-128_bias.fit
# 232 dark_190504_AD-129_bias.fit
# 233 dark_190504_AD-130_bias.fit
# 234 dark_190504_AD-131_bias.fit
# 235 dark_190504_AD-132_bias.fit
# 236 dark_190504_AD-133_bias.fit
# 237 dark_190504_AD-134_bias.fit
# 238 dark_190504_AD-135_bias.fit
# 239 dark_190504_AD-136_bias.fit
# 240 dark_190504_AD-137_bias.fit
# 241 dark_190504_AD-138_bias.fit
# 242 dark_190504_AD-139_bias.fit
# 243 dark_190504_AD-140_bias.fit
# 244 dark_190504_AD-141_bias.fit
# 245 dark_190504_AD-142_bias.fit
# 246 dark_190504_AD-143_bias.fit
# 247 dark_190504_AD-144_bias.fit
# 248 dark_190504_AD-145_bias.fit
# 249 dark_190504_AD-146_bias.fit
# 250 dark_190504_AD-147_bias.fit
# 251 dark_190504_AD-148_bias.fit
# 252 dark_190504_AD-149_bias.fit
# 253 dark_190504_AD-150_bias.fit
# 254 dark_190504_AD-151_bias.fit
# 255 dark_190504_AD-152_bias.fit
# 256 dark_190504_AD-153_bias.fit
# 257 dark_190504_AD-157_bias.fit
# 258 dark_190504_AD-158_bias.fit
# 259 dark_190504_AD-159_bias.fit
# 260 dark_190504_AD-160_bias.fit
# 261 dark_190504_AD-161_bias.fit
# 262 dark_190504_AD-162_bias.fit
# 263 dark_190504_AD-163_bias.fit
# 264 dark_190504_AD-164_bias.fit
# 265 dark_190504_AD-165_bias.fit
# 266 dark_190504_AD-166_bias.fit
# 267 dark_190504_AD-167_bias.fit
# 268 dark_190504_AD-168_bias.fit
# 269 dark_190504_AD-169_bias.fit
# 270 dark_190504_AD-170_bias.fit
# 271 dark_190504_AD-171_bias.fit
# 272 dark_190504_AD-172_bias.fit
# 273 dark_190504_AD-173_bias.fit
# 274 dark_190504_AD-174_bias.fit
# 275 dark_190504_AD-175_bias.fit
# 276 dark_190504_AD-176_bias.fit
# 277 dark_190504_AD-177_bias.fit
# 278 dark_190504_AD-178_bias.fit
# 279 dark_190504_AD-179_bias.fit
# 280 dark_190504_AD-180_bias.fit
# 281 dark_190504_AD-181_bias.fit
# 282 dark_190504_AD-182_bias.fit
# 283 dark_190504_AD-183_bias.fit
# 284 dark_190504_AD-184_bias.fit
# 285 dark_190504_AD-185_bias.fit
# 286 dark_190504_AD-186_bias.fit
# 287 dark_190504_AD-187_bias.fit
# 288 dark_190504_AD-188_bias.fit
# 289 dark_190504_AD-189_bias.fit
# 290 dark_190504_AD-190_bias.fit
# 291 dark_190504_AD-191_bias.fit
# 292 dark_190504_AD-192_bias.fit
# 293 dark_190504_AD-193_bias.fit
# 294 dark_190504_AD-194_bias.fit
# 295 dark_190504_AD-195_bias.fit
# 296 dark_190504_AD-196_bias.fit
# 297 dark_190504_AD-197_bias.fit
# 298 dark_190504_AD-198_bias.fit
# 299 dark_190504_AD-199_bias.fit
# 300 dark_190504_AD-200_bias.fit

# %% [markdown]
# # Task 1. Creating Faulty Non-Noisy Pixels Fits

# %%
'''Make a stack of images, a list of headers from those images, and calculate some medians and stds
that will help set autoscaling parameters.'''


image = np.zeros((len(files), 1024,1024))
imedian = np.zeros((len(files)))          
istd = np.zeros((len(files)))              
madstd = np.zeros((len(files))) 
headlist = []  
print('image.shape =', image.shape)
for i in range(len(files)):


#############################################################################
    # Use this code block if you want to use the standard astropy.io package.
    fitsfilename = os.path.join(datapath, files[i])    # Full path to a fitsfile.
    hdulist = fits.open(fitsfilename)                  # Open a fits file as an hdulist object.
    hdu0 = hdulist[0]                                  # Define a fits object as the 0th hdu in the fitsfile.
    image[i] = hdu0.data * 1.0                         # Define image in stack as float of data in the 0th hdu.
    headlist.append(hdu0.header)                       # Append the header of the fits object to the header list.
    print('')
    print(i,files[i])
###############################################################################    
    
    ## Calculate some medians and stds to use in autoscaling that aren't unduly biased by extreme values.
    ## Optionally, print out masked and unmasked values to explore the effects of extreme values on the statistics.
    
    madstd[i] = mad_std(image[i],ignore_nan=True)
    imedian[i] = np.nanmedian(image[i])
    istd[i] = np.nanstd(image[i])
# Out:
# image.shape = (301, 1024, 1024)
#
# 0 dark_190421_AA-001_bias.fit
#
# 1 dark_190421_AA-002_bias.fit
#
# 2 dark_190421_AA-003_bias.fit
#
# 3 dark_190421_AA-004_bias.fit
#
# 4 dark_190421_AA-005_bias.fit
#
# 5 dark_190421_AA-006_bias.fit
#
# 6 dark_190421_AA-007_bias.fit
#
# 7 dark_190421_AA-008_bias.fit
#
# 8 dark_190421_AA-009_bias.fit
#
# 9 dark_190421_AA-010_bias.fit
#
# 10 dark_190421_AA-011_bias.fit
#
# 11 dark_190421_AA-012_bias.fit
#
# 12 dark_190421_AA-013_bias.fit
#
# 13 dark_190421_AA-014_bias.fit
#
# 14 dark_190421_AA-015_bias.fit
#
# 15 dark_190421_AA-016_bias.fit
#
# 16 dark_190421_AA-017_bias.fit
#
# 17 dark_190421_AA-018_bias.fit
#
# 18 dark_190421_AA-019_bias.fit
#
# 19 dark_190421_AA-020_bias.fit
#
# 20 dark_190421_AA-021_bias.fit
#
# 21 dark_190421_AA-022_bias.fit
#
# 22 dark_190421_AA-023_bias.fit
#
# 23 dark_190421_AA-024_bias.fit
#
# 24 dark_190421_AA-025_bias.fit
#
# 25 dark_190421_AA-026_bias.fit
#
# 26 dark_190421_AA-027_bias.fit
#
# 27 dark_190421_AA-028_bias.fit
#
# 28 dark_190421_AA-029_bias.fit
#
# 29 dark_190421_AA-030_bias.fit
#
# 30 dark_190504_AB-001_bias.fit
#
# 31 dark_190504_AB-002_bias.fit
#
# 32 dark_190504_AB-003_bias.fit
#
# 33 dark_190504_AB-004_bias.fit
#
# 34 dark_190504_AB-005_bias.fit
#
# 35 dark_190504_AB-006_bias.fit
#
# 36 dark_190504_AB-007_bias.fit
#
# 37 dark_190504_AB-008_bias.fit
#
# 38 dark_190504_AB-009_bias.fit
#
# 39 dark_190504_AB-010_bias.fit
#
# 40 dark_190504_AB-011_bias.fit
#
# 41 dark_190504_AB-012_bias.fit
#
# 42 dark_190504_AB-013_bias.fit
#
# 43 dark_190504_AB-014_bias.fit
#
# 44 dark_190504_AB-015_bias.fit
#
# 45 dark_190504_AB-016_bias.fit
#
# 46 dark_190504_AB-017_bias.fit
#
# 47 dark_190504_AB-018_bias.fit
#
# 48 dark_190504_AB-019_bias.fit
#
# 49 dark_190504_AB-020_bias.fit
#
# 50 dark_190504_AB-021_bias.fit
#
# 51 dark_190504_AB-022_bias.fit
#
# 52 dark_190504_AB-023_bias.fit
#
# 53 dark_190504_AB-024_bias.fit
#
# 54 dark_190504_AB-025_bias.fit
#
# 55 dark_190504_AB-026_bias.fit
#
# 56 dark_190504_AB-027_bias.fit
#
# 57 dark_190504_AB-028_bias.fit
#
# 58 dark_190504_AB-029_bias.fit
#
# 59 dark_190504_AB-030_bias.fit
#
# 60 dark_190504_AB-031_bias.fit
#
# 61 dark_190504_AB-032_bias.fit
#
# 62 dark_190504_AB-033_bias.fit
#
# 63 dark_190504_AB-034_bias.fit
#
# 64 dark_190504_AB-035_bias.fit
#
# 65 dark_190504_AB-036_bias.fit
#
# 66 dark_190504_AB-037_bias.fit
#
# 67 dark_190504_AB-038_bias.fit
#
# 68 dark_190504_AB-039_bias.fit
#
# 69 dark_190504_AB-040_bias.fit
#
# 70 dark_190504_AB-041_bias.fit
#
# 71 dark_190504_AB-042_bias.fit
#
# 72 dark_190504_AB-043_bias.fit
#
# 73 dark_190504_AB-044_bias.fit
#
# 74 dark_190504_AB-045_bias.fit
#
# 75 dark_190504_AB-046_bias.fit
#
# 76 dark_190504_AB-047_bias.fit
#
# 77 dark_190504_AB-048_bias.fit
#
# 78 dark_190504_AB-049_bias.fit
#
# 79 dark_190504_AB-050_bias.fit
#
# 80 dark_190504_AC-001_bias.fit
#
# 81 dark_190504_AC-002_bias.fit
#
# 82 dark_190504_AC-003_bias.fit
#
# 83 dark_190504_AC-004_bias.fit
#
# 84 dark_190504_AC-005_bias.fit
#
# 85 dark_190504_AC-006_bias.fit
#
# 86 dark_190504_AC-007_bias.fit
#
# 87 dark_190504_AC-008_bias.fit
#
# 88 dark_190504_AC-009_bias.fit
#
# 89 dark_190504_AC-010_bias.fit
#
# 90 dark_190504_AC-011_bias.fit
#
# 91 dark_190504_AC-012_bias.fit
#
# 92 dark_190504_AC-013_bias.fit
#
# 93 dark_190504_AC-014_bias.fit
#
# 94 dark_190504_AC-015_bias.fit
#
# 95 dark_190504_AC-016_bias.fit
#
# 96 dark_190504_AC-017_bias.fit
#
# 97 dark_190504_AC-018_bias.fit
#
# 98 dark_190504_AC-019_bias.fit
#
# 99 dark_190504_AC-020_bias.fit
#
# 100 dark_190504_AC-021_bias.fit
#
# 101 dark_190504_AC-022_bias.fit
#
# 102 dark_190504_AC-023_bias.fit
#
# 103 dark_190504_AC-024_bias.fit
#
# 104 dark_190504_AC-025_bias.fit
#
# 105 dark_190504_AD-001_bias.fit
#
# 106 dark_190504_AD-002_bias.fit
#
# 107 dark_190504_AD-003_bias.fit
#
# 108 dark_190504_AD-004_bias.fit
#
# 109 dark_190504_AD-005_bias.fit
#
# 110 dark_190504_AD-006_bias.fit
#
# 111 dark_190504_AD-007_bias.fit
#
# 112 dark_190504_AD-008_bias.fit
#
# 113 dark_190504_AD-009_bias.fit
#
# 114 dark_190504_AD-010_bias.fit
#
# 115 dark_190504_AD-011_bias.fit
#
# 116 dark_190504_AD-012_bias.fit
#
# 117 dark_190504_AD-013_bias.fit
#
# 118 dark_190504_AD-014_bias.fit
#
# 119 dark_190504_AD-015_bias.fit
#
# 120 dark_190504_AD-016_bias.fit
#
# 121 dark_190504_AD-017_bias.fit
#
# 122 dark_190504_AD-018_bias.fit
#
# 123 dark_190504_AD-019_bias.fit
#
# 124 dark_190504_AD-020_bias.fit
#
# 125 dark_190504_AD-021_bias.fit
#
# 126 dark_190504_AD-022_bias.fit
#
# 127 dark_190504_AD-023_bias.fit
#
# 128 dark_190504_AD-024_bias.fit
#
# 129 dark_190504_AD-025_bias.fit
#
# 130 dark_190504_AD-026_bias.fit
#
# 131 dark_190504_AD-027_bias.fit
#
# 132 dark_190504_AD-028_bias.fit
#
# 133 dark_190504_AD-029_bias.fit
#
# 134 dark_190504_AD-030_bias.fit
#
# 135 dark_190504_AD-031_bias.fit
#
# 136 dark_190504_AD-032_bias.fit
#
# 137 dark_190504_AD-033_bias.fit
#
# 138 dark_190504_AD-034_bias.fit
#
# 139 dark_190504_AD-035_bias.fit
#
# 140 dark_190504_AD-036_bias.fit
#
# 141 dark_190504_AD-037_bias.fit
#
# 142 dark_190504_AD-038_bias.fit
#
# 143 dark_190504_AD-039_bias.fit
#
# 144 dark_190504_AD-040_bias.fit
#
# 145 dark_190504_AD-041_bias.fit
#
# 146 dark_190504_AD-042_bias.fit
#
# 147 dark_190504_AD-043_bias.fit
#
# 148 dark_190504_AD-044_bias.fit
#
# 149 dark_190504_AD-045_bias.fit
#
# 150 dark_190504_AD-046_bias.fit
#
# 151 dark_190504_AD-047_bias.fit
#
# 152 dark_190504_AD-048_bias.fit
#
# 153 dark_190504_AD-049_bias.fit
#
# 154 dark_190504_AD-050_bias.fit
#
# 155 dark_190504_AD-051_bias.fit
#
# 156 dark_190504_AD-052_bias.fit
#
# 157 dark_190504_AD-053_bias.fit
#
# 158 dark_190504_AD-054_bias.fit
#
# 159 dark_190504_AD-055_bias.fit
#
# 160 dark_190504_AD-056_bias.fit
#
# 161 dark_190504_AD-057_bias.fit
#
# 162 dark_190504_AD-058_bias.fit
#
# 163 dark_190504_AD-059_bias.fit
#
# 164 dark_190504_AD-060_bias.fit
#
# 165 dark_190504_AD-061_bias.fit
#
# 166 dark_190504_AD-062_bias.fit
#
# 167 dark_190504_AD-063_bias.fit
#
# 168 dark_190504_AD-064_bias.fit
#
# 169 dark_190504_AD-065_bias.fit
#
# 170 dark_190504_AD-066_bias.fit
#
# 171 dark_190504_AD-067_bias.fit
#
# 172 dark_190504_AD-068_bias.fit
#
# 173 dark_190504_AD-069_bias.fit
#
# 174 dark_190504_AD-070_bias.fit
#
# 175 dark_190504_AD-071_bias.fit
#
# 176 dark_190504_AD-072_bias.fit
#
# 177 dark_190504_AD-073_bias.fit
#
# 178 dark_190504_AD-074_bias.fit
#
# 179 dark_190504_AD-075_bias.fit
#
# 180 dark_190504_AD-076_bias.fit
#
# 181 dark_190504_AD-077_bias.fit
#
# 182 dark_190504_AD-078_bias.fit
#
# 183 dark_190504_AD-079_bias.fit
#
# 184 dark_190504_AD-080_bias.fit
#
# 185 dark_190504_AD-081_bias.fit
#
# 186 dark_190504_AD-082_bias.fit
#
# 187 dark_190504_AD-083_bias.fit
#
# 188 dark_190504_AD-084_bias.fit
#
# 189 dark_190504_AD-085_bias.fit
#
# 190 dark_190504_AD-086_bias.fit
#
# 191 dark_190504_AD-087_bias.fit
#
# 192 dark_190504_AD-088_bias.fit
#
# 193 dark_190504_AD-089_bias.fit
#
# 194 dark_190504_AD-090_bias.fit
#
# 195 dark_190504_AD-091_bias.fit
#
# 196 dark_190504_AD-092_bias.fit
#
# 197 dark_190504_AD-093_bias.fit
#
# 198 dark_190504_AD-094_bias.fit
#
# 199 dark_190504_AD-095_bias.fit
#
# 200 dark_190504_AD-096_bias.fit
#
# 201 dark_190504_AD-098_bias.fit
#
# 202 dark_190504_AD-099_bias.fit
#
# 203 dark_190504_AD-100_bias.fit
#
# 204 dark_190504_AD-101_bias.fit
#
# 205 dark_190504_AD-102_bias.fit
#
# 206 dark_190504_AD-103_bias.fit
#
# 207 dark_190504_AD-104_bias.fit
#
# 208 dark_190504_AD-105_bias.fit
#
# 209 dark_190504_AD-106_bias.fit
#
# 210 dark_190504_AD-107_bias.fit
#
# 211 dark_190504_AD-108_bias.fit
#
# 212 dark_190504_AD-109_bias.fit
#
# 213 dark_190504_AD-110_bias.fit
#
# 214 dark_190504_AD-111_bias.fit
#
# 215 dark_190504_AD-112_bias.fit
#
# 216 dark_190504_AD-113_bias.fit
#
# 217 dark_190504_AD-114_bias.fit
#
# 218 dark_190504_AD-115_bias.fit
#
# 219 dark_190504_AD-116_bias.fit
#
# 220 dark_190504_AD-117_bias.fit
#
# 221 dark_190504_AD-118_bias.fit
#
# 222 dark_190504_AD-119_bias.fit
#
# 223 dark_190504_AD-120_bias.fit
#
# 224 dark_190504_AD-121_bias.fit
#
# 225 dark_190504_AD-122_bias.fit
#
# 226 dark_190504_AD-123_bias.fit
#
# 227 dark_190504_AD-124_bias.fit
#
# 228 dark_190504_AD-125_bias.fit
#
# 229 dark_190504_AD-126_bias.fit
#
# 230 dark_190504_AD-127_bias.fit
#
# 231 dark_190504_AD-128_bias.fit
#
# 232 dark_190504_AD-129_bias.fit
#
# 233 dark_190504_AD-130_bias.fit
#
# 234 dark_190504_AD-131_bias.fit
#
# 235 dark_190504_AD-132_bias.fit
#
# 236 dark_190504_AD-133_bias.fit
#
# 237 dark_190504_AD-134_bias.fit
#
# 238 dark_190504_AD-135_bias.fit
#
# 239 dark_190504_AD-136_bias.fit
#
# 240 dark_190504_AD-137_bias.fit
#
# 241 dark_190504_AD-138_bias.fit
#
# 242 dark_190504_AD-139_bias.fit
#
# 243 dark_190504_AD-140_bias.fit
#
# 244 dark_190504_AD-141_bias.fit
#
# 245 dark_190504_AD-142_bias.fit
#
# 246 dark_190504_AD-143_bias.fit
#
# 247 dark_190504_AD-144_bias.fit
#
# 248 dark_190504_AD-145_bias.fit
#
# 249 dark_190504_AD-146_bias.fit
#
# 250 dark_190504_AD-147_bias.fit
#
# 251 dark_190504_AD-148_bias.fit
# 252 dark_190504_AD-149_bias.fit
#
# 253 dark_190504_AD-150_bias.fit
#
# 254 dark_190504_AD-151_bias.fit
#
# 255 dark_190504_AD-152_bias.fit
#
# 256 dark_190504_AD-153_bias.fit
#
# 257 dark_190504_AD-157_bias.fit
#
# 258 dark_190504_AD-158_bias.fit
#
# 259 dark_190504_AD-159_bias.fit
#
# 260 dark_190504_AD-160_bias.fit
#
# 261 dark_190504_AD-161_bias.fit
#
# 262 dark_190504_AD-162_bias.fit
#
# 263 dark_190504_AD-163_bias.fit
#
# 264 dark_190504_AD-164_bias.fit
#
# 265 dark_190504_AD-165_bias.fit
#
# 266 dark_190504_AD-166_bias.fit
#
# 267 dark_190504_AD-167_bias.fit
#
# 268 dark_190504_AD-168_bias.fit
#
# 269 dark_190504_AD-169_bias.fit
#
# 270 dark_190504_AD-170_bias.fit
#
# 271 dark_190504_AD-171_bias.fit
#
# 272 dark_190504_AD-172_bias.fit
#
# 273 dark_190504_AD-173_bias.fit
#
# 274 dark_190504_AD-174_bias.fit
#
# 275 dark_190504_AD-175_bias.fit
#
# 276 dark_190504_AD-176_bias.fit
#
# 277 dark_190504_AD-177_bias.fit
#
# 278 dark_190504_AD-178_bias.fit
#
# 279 dark_190504_AD-179_bias.fit
#
# 280 dark_190504_AD-180_bias.fit
#
# 281 dark_190504_AD-181_bias.fit
#
# 282 dark_190504_AD-182_bias.fit
#
# 283 dark_190504_AD-183_bias.fit
#
# 284 dark_190504_AD-184_bias.fit
#
# 285 dark_190504_AD-185_bias.fit
#
# 286 dark_190504_AD-186_bias.fit
#
# 287 dark_190504_AD-187_bias.fit
#
# 288 dark_190504_AD-188_bias.fit
#
# 289 dark_190504_AD-189_bias.fit
#
# 290 dark_190504_AD-190_bias.fit
#
# 291 dark_190504_AD-191_bias.fit
#
# 292 dark_190504_AD-192_bias.fit
#
# 293 dark_190504_AD-193_bias.fit
#
# 294 dark_190504_AD-194_bias.fit
#
# 295 dark_190504_AD-195_bias.fit
#
# 296 dark_190504_AD-196_bias.fit
#
# 297 dark_190504_AD-197_bias.fit
#
# 298 dark_190504_AD-198_bias.fit
#
# 299 dark_190504_AD-199_bias.fit
#
# 300 dark_190504_AD-200_bias.fit

# %%
bad = 0
for i in range(len(image)):
    istand = image[i] - imedian[i]
    bad += (istand > istd[i])
    bad += (istand < -istd[i])
for j in range(len(sum(bad))):
    print(str(j) + ':' + str(sum(bad)[j]))
# Out:
# 0:92637
# 1:98701
# 2:84049
# 3:77441
# 4:72619
# 5:72022
# 6:67821
# 7:66289
# 8:78392
# 9:59800
# 10:57317
# 11:92115
# 12:57178
# 13:63431
# 14:51272
# 15:52987
# 16:47598
# 17:50281
# 18:59729
# 19:32926
# 20:50914
# 21:43172
# 22:49499
# 23:41945
# 24:45537
# 25:37168
# 26:40795
# 27:44781
# 28:36905
# 29:38441
# 30:37169
# 31:36411
# 32:34183
# 33:33898
# 34:32511
# 35:34997
# 36:31733
# 37:29822
# 38:28798
# 39:29412
# 40:27145
# 41:27243
# 42:26498
# 43:27789
# 44:27045
# 45:23702
# 46:23912
# 47:24394
# 48:23359
# 49:22577
# 50:22231
# 51:21528
# 52:21363
# 53:20112
# 54:23045
# 55:18415
# 56:21022
# 57:18596
# 58:20379
# 59:22573
# 60:17895
# 61:19564
# 62:18576
# 63:19573
# 64:17689
# 65:18811
# 66:20910
# 67:17474
# 68:18133
# 69:15359
# 70:17004
# 71:17106
# 72:17098
# 73:19701
# 74:15673
# 75:14952
# 76:15160
# 77:14472
# 78:13737
# 79:13940
# 80:19590
# 81:13194
# 82:12778
# 83:12793
# 84:12551
# 85:12391
# 86:12687
# 87:39141
# 88:11798
# 89:12335
# 90:11156
# 91:11457
# 92:10995
# 93:11409
# 94:10819
# 95:13318
# 96:10706
# 97:10257
# 98:10598
# 99:9571
# 100:10538
# 101:9742
# 102:9402
# 103:10809
# 104:9409
# 105:9795
# 106:9362
# 107:9456
# 108:9407
# 109:8853
# 110:8601
# 111:8719
# 112:9111
# 113:8695
# 114:8593
# 115:8843
# 116:8114
# 117:8247
# 118:8153
# 119:8258
# 120:8240
# 121:7620
# 122:8295
# 123:14272
# 124:7626
# 125:7632
# 126:7542
# 127:7217
# 128:7021
# 129:7759
# 130:7087
# 131:7080
# 132:6797
# 133:6817
# 134:7130
# 135:6812
# 136:6592
# 137:6612
# 138:6267
# 139:6497
# 140:6261
# 141:6196
# 142:6581
# 143:6533
# 144:6226
# 145:6223
# 146:6048
# 147:6070
# 148:6256
# 149:6020
# 150:6387
# 151:5825
# 152:5996
# 153:5923
# 154:6281
# 155:5786
# 156:5799
# 157:5730
# 158:5581
# 159:5410
# 160:12968
# 161:6158
# 162:5515
# 163:6488
# 164:5414
# 165:5277
# 166:5200
# 167:5301
# 168:5089
# 169:5544
# 170:5380
# 171:5169
# 172:5492
# 173:5284
# 174:4989
# 175:5115
# 176:5146
# 177:4819
# 178:4872
# 179:4919
# 180:5012
# 181:4878
# 182:4955
# 183:4744
# 184:4872
# 185:4830
# 186:4556
# 187:4514
# 188:4540
# 189:4514
# 190:4593
# 191:4592
# 192:4652
# 193:4454
# 194:4594
# 195:4438
# 196:4767
# 197:4547
# 198:4480
# 199:4726
# 200:4486
# 201:4364
# 202:4334
# 203:4446
# 204:4355
# 205:4379
# 206:4350
# 207:4373
# 208:4183
# 209:4275
# 210:4206
# 211:4410
# 212:4050
# 213:4155
# 214:4299
# 215:4119
# 216:4419
# 217:6352
# 218:4109
# 219:4327
# 220:4300
# 221:4297
# 222:4512
# 223:4076
# 224:4039
# 225:5112
# 226:4147
# 227:9908
# 228:4228
# 229:4260
# 230:5004
# 231:4125
# 232:3873
# 233:4076
# 234:4019
# 235:4041
# 236:3874
# 237:4085
# 238:4107
# 239:3984
# 240:4098
# 241:3976
# 242:4081
# 243:4078
# 244:3864
# 245:3839
# 246:3852
# 247:3959
# 248:4059
# 249:3922
# 250:3873
# 251:3877
# 252:3845
# 253:3869
# 254:3888
# 255:3901
# 256:4152
# 257:3924
# 258:4192
# 259:3883
# 260:4266
# 261:3850
# 262:3902
# 263:4150
# 264:3840
# 265:4173
# 266:3950
# 267:3879
# 268:3885
# 269:3924
# 270:3976
# 271:4093
# 272:4018
# 273:3754
# 274:3855
# 275:3899
# 276:3876
# 277:3888
# 278:3772
# 279:3853
# 280:4009
# 281:3877
# 282:3927
# 283:3839
# 284:3941
# 285:4172
# 286:12924
# 287:4091
# 288:4170
# 289:3728
# 290:3960
# 291:4345
# 292:3876
# 293:3812
# 294:3766
# 295:4125
# 296:4119
# 297:3739
# 298:3799
# 299:3673
# 300:3886
# 301:6895
# 302:3753
# 303:3935
# 304:3983
# 305:3965
# 306:7757
# 307:3653
# 308:4047
# 309:3991
# 310:4017
# 311:3883
# 312:3813
# 313:3927
# 314:3834
# 315:3886
# 316:4185
# 317:4381
# 318:4078
# 319:4077
# 320:4173
# 321:3775
# 322:3872
# 323:3933
# 324:3957
# 325:4951
# 326:3791
# 327:3899
# 328:3885
# 329:3862
# 330:3938
# 331:3987
# 332:3858
# 333:3851
# 334:3991
# 335:3869
# 336:4035
# 337:3866
# 338:3838
# 339:3885
# 340:3922
# 341:4029
# 342:4078
# 343:3794
# 344:3848
# 345:4113
# 346:3860
# 347:3725
# 348:3741
# 349:4009
# 350:3795
# 351:4248
# 352:3952
# 353:3973
# 354:4374
# 355:4065
# 356:3951
# 357:4254
# 358:3866
# 359:10280
# 360:3768
# 361:3859
# 362:4076
# 363:3984
# 364:3952
# 365:4215
# 366:4130
# 367:4013
# 368:3990
# 369:3870
# 370:4128
# 371:3954
# 372:3974
# 373:4048
# 374:4344
# 375:4123
# 376:4006
# 377:4221
# 378:3956
# 379:3898
# 380:3978
# 381:4072
# 382:4126
# 383:4081
# 384:4020
# 385:4218
# 386:4093
# 387:4038
# 388:4231
# 389:4251
# 390:4073
# 391:4487
# 392:3947
# 393:4200
# 394:4028
# 395:4248
# 396:7566
# 397:4068
# 398:4011
# 399:4079
# 400:3952
# 401:4169
# 402:3987
# 403:4004
# 404:4007
# 405:4112
# 406:4274
# 407:4262
# 408:4054
# 409:4233
# 410:4183
# 411:4093
# 412:4095
# 413:4091
# 414:4301
# 415:4050
# 416:4257
# 417:4200
# 418:4225
# 419:4335
# 420:4183
# 421:4145
# 422:4317
# 423:4190
# 424:4151
# 425:4294
# 426:4893
# 427:4407
# 428:4068
# 429:4232
# 430:4321
# 431:4237
# 432:4174
# 433:4530
# 434:4306
# 435:4420
# 436:4469
# 437:4229
# 438:4269
# 439:4320
# 440:4166
# 441:4393
# 442:4115
# 443:4383
# 444:4255
# 445:4057
# 446:4216
# 447:4095
# 448:4247
# 449:4028
# 450:4292
# 451:4426
# 452:4117
# 453:4155
# 454:4372
# 455:4280
# 456:4222
# 457:4325
# 458:4224
# 459:4679
# 460:4547
# 461:4365
# 462:4251
# 463:4314
# 464:4238
# 465:4296
# 466:4668
# 467:4486
# 468:4324
# 469:4250
# 470:4269
# 471:4224
# 472:4240
# 473:4318
# 474:4301
# 475:4342
# 476:4329
# 477:4291
# 478:4514
# 479:11955
# 480:4922
# 481:4268
# 482:4280
# 483:4204
# 484:4580
# 485:4268
# 486:4471
# 487:4445
# 488:4423
# 489:5735
# 490:4282
# 491:4283
# 492:4375
# 493:4524
# 494:4729
# 495:4488
# 496:4352
# 497:4631
# 498:4345
# 499:4585
# 500:4357
# 501:4340
# 502:4374
# 503:4597
# 504:4358
# 505:4397
# 506:4494
# 507:4836
# 508:4319
# 509:4401
# 510:4466
# 511:4345
# 512:4416
# 513:7280
# 514:4565
# 515:4631
# 516:4351
# 517:4456
# 518:4691
# 519:4525
# 520:6678
# 521:4231
# 522:4375
# 523:4459
# 524:4549
# 525:5069
# 526:4366
# 527:4634
# 528:4602
# 529:4648
# 530:4412
# 531:4605
# 532:4508
# 533:4565
# 534:4465
# 535:4864
# 536:4412
# 537:4597
# 538:4507
# 539:4437
# 540:4348
# 541:4334
# 542:4453
# 543:4517
# 544:4702
# 545:4700
# 546:4652
# 547:4740
# 548:4558
# 549:4805
# 550:4584
# 551:4767
# 552:4515
# 553:4517
# 554:4744
# 555:4568
# 556:4708
# 557:4465
# 558:4704
# 559:4609
# 560:4630
# 561:4595
# 562:4588
# 563:4534
# 564:4622
# 565:4474
# 566:4811
# 567:4750
# 568:4641
# 569:4530
# 570:4676
# 571:4542
# 572:4651
# 573:4420
# 574:4722
# 575:4538
# 576:4640
# 577:4987
# 578:4768
# 579:4687
# 580:4557
# 581:4476
# 582:4447
# 583:5211
# 584:4421
# 585:4661
# 586:4792
# 587:4522
# 588:4534
# 589:4662
# 590:4420
# 591:4415
# 592:4575
# 593:4392
# 594:4388
# 595:4396
# 596:119219
# 597:4481
# 598:4617
# 599:4548
# 600:4512
# 601:4568
# 602:4507
# 603:4548
# 604:4659
# 605:4438
# 606:4753
# 607:4429
# 608:4625
# 609:4737
# 610:4602
# 611:4599
# 612:4805
# 613:4681
# 614:4674
# 615:4747
# 616:4898
# 617:4827
# 618:4737
# 619:4749
# 620:4794
# 621:4907
# 622:4678
# 623:4941
# 624:4587
# 625:4602
# 626:4685
# 627:4685
# 628:4847
# 629:4652
# 630:4567
# 631:4650
# 632:4614
# 633:4782
# 634:4503
# 635:6795
# 636:9361
# 637:4690
# 638:4507
# 639:4631
# 640:4835
# 641:4591
# 642:4686
# 643:4728
# 644:4798
# 645:4789
# 646:4693
# 647:4726
# 648:5038
# 649:4868
# 650:230166
# 651:4485
# 652:4648
# 653:4761
# 654:4651
# 655:4865
# 656:4843
# 657:4674
# 658:4633
# 659:4824
# 660:4798
# 661:4802
# 662:5490
# 663:4745
# 664:4643
# 665:4941
# 666:4600
# 667:4808
# 668:4593
# 669:4680
# 670:4572
# 671:4588
# 672:4705
# 673:5200
# 674:4850
# 675:4865
# 676:4699
# 677:4793
# 678:4754
# 679:4813
# 680:4971
# 681:4809
# 682:4819
# 683:4713
# 684:4806
# 685:4687
# 686:4836
# 687:4668
# 688:4864
# 689:4664
# 690:4715
# 691:4644
# 692:5010
# 693:4641
# 694:4676
# 695:4650
# 696:4704
# 697:4704
# 698:4853
# 699:4755
# 700:4588
# 701:4720
# 702:4564
# 703:4790
# 704:4627
# 705:4724
# 706:4863
# 707:4952
# 708:4840
# 709:4847
# 710:4799
# 711:9209
# 712:4613
# 713:4751
# 714:4754
# 715:4798
# 716:4743
# 717:4601
# 718:4901
# 719:4962
# 720:4628
# 721:4712
# 722:4728
# 723:4553
# 724:4781
# 725:4767
# 726:187579
# 727:4585
# 728:4746
# 729:4566
# 730:4977
# 731:4780
# 732:4659
# 733:4562
# 734:4934
# 735:4718
# 736:4851
# 737:4743
# 738:4957
# 739:4764
# 740:4897
# 741:5024
# 742:4753
# 743:5108
# 744:4728
# 745:4819
# 746:4783
# 747:4714
# 748:4811
# 749:4923
# 750:5179
# 751:4773
# 752:4711
# 753:4802
# 754:4751
# 755:4742
# 756:5018
# 757:4794
# 758:4980
# 759:4764
# 760:4683
# 761:5311
# 762:4884
# 763:5256
# 764:4773
# 765:4925
# 766:4833
# 767:7072
# 768:4917
# 769:4808
# 770:4774
# 771:5023
# 772:4762
# 773:5116
# 774:5846
# 775:10575
# 776:5230
# 777:4745
# 778:5061
# 779:4788
# 780:4843
# 781:4768
# 782:4793
# 783:5066
# 784:5149
# 785:4827
# 786:4802
# 787:4813
# 788:4693
# 789:4592
# 790:5099
# 791:4939
# 792:4642
# 793:4730
# 794:4752
# 795:4768
# 796:4993
# 797:4790
# 798:4991
# 799:4864
# 800:4866
# 801:4881
# 802:4838
# 803:4880
# 804:4684
# 805:4982
# 806:4974
# 807:5119
# 808:4822
# 809:5702
# 810:4788
# 811:4987
# 812:4993
# 813:4838
# 814:4861
# 815:4801
# 816:4824
# 817:4709
# 818:5104
# 819:4785
# 820:4893
# 821:4898
# 822:5341
# 823:5095
# 824:4917
# 825:4895
# 826:4919
# 827:4957
# 828:4842
# 829:5022
# 830:4929
# 831:4984
# 832:4927
# 833:4976
# 834:5028
# 835:5002
# 836:4938
# 837:4829
# 838:4948
# 839:4766
# 840:4822
# 841:4779
# 842:4771
# 843:5073
# 844:4719
# 845:4764
# 846:4808
# 847:4790
# 848:4815
# 849:5090
# 850:4827
# 851:4895
# 852:4991
# 853:9850
# 854:4788
# 855:4772
# 856:4623
# 857:4875
# 858:4880
# 859:5149
# 860:5012
# 861:4812
# 862:5002
# 863:4875
# 864:5102
# 865:5037
# 866:4855
# 867:4930
# 868:5051
# 869:5296
# 870:4965
# 871:5220
# 872:4946
# 873:4994
# 874:4991
# 875:5030
# 876:4884
# 877:4948
# 878:5048
# 879:5134
# 880:5058
# 881:5252
# 882:4838
# 883:5055
# 884:4936
# 885:4809
# 886:5017
# 887:4809
# 888:11857
# 889:4772
# 890:4920
# 891:4855
# 892:4880
# 893:5331
# 894:6572
# 895:4928
# 896:4863
# 897:4834
# 898:4859
# 899:4860
# 900:4846
# 901:4740
# 902:4989
# 903:4924
# 904:5096
# 905:4804
# 906:5351
# 907:4917
# 908:4759
# 909:4852
# 910:4862
# 911:4948
# 912:4664
# 913:5019
# 914:4738
# 915:4962
# 916:4899
# 917:4925
# 918:5006
# 919:4845
# 920:4900
# 921:4816
# 922:4937
# 923:4915
# 924:5000
# 925:4975
# 926:4960
# 927:4900
# 928:5016
# 929:4930
# 930:4858
# 931:5174
# 932:4980
# 933:4990
# 934:4920
# 935:5098
# 936:5173
# 937:5066
# 938:5995
# 939:4978
# 940:4923
# 941:4913
# 942:4897
# 943:4912
# 944:4981
# 945:4969
# 946:4781
# 947:5757
# 948:5053
# 949:5032
# 950:4843
# 951:4869
# 952:4734
# 953:4744
# 954:4877
# 955:5179
# 956:5101
# 957:4969
# 958:5043
# 959:4847
# 960:4896
# 961:4930
# 962:4828
# 963:5024
# 964:4886
# 965:5046
# 966:4828
# 967:4912
# 968:5056
# 969:4896
# 970:5281
# 971:4723
# 972:5089
# 973:4828
# 974:4934
# 975:4803
# 976:4753
# 977:4790
# 978:4864
# 979:4766
# 980:4811
# 981:4805
# 982:4815
# 983:4951
# 984:4867
# 985:4821
# 986:5052
# 987:4911
# 988:4935
# 989:5156
# 990:4874
# 991:4870
# 992:5207
# 993:5421
# 994:4978
# 995:4876
# 996:4858
# 997:5101
# 998:5055
# 999:5107
# 1000:4816
# 1001:5006
# 1002:4916
# 1003:4992
# 1004:5009
# 1005:224364
# 1006:4478
# 1007:4940
# 1008:4770
# 1009:5095
# 1010:4732
# 1011:4784
# 1012:4730
# 1013:4817
# 1014:4649
# 1015:5147
# 1016:4807
# 1017:4938
# 1018:4845
# 1019:9133
# 1020:4591
# 1021:4827
# 1022:4636
# 1023:4586

# %%
#Creating a map of how often the pixels have been bad

bads = np.zeros((1024,1024))

imedian2 = np.zeros((len(files)))           # 1D numpy array to hold array medians.
istd2 = np.zeros((len(files)))              # 1D numpy array to hold array stds.

for i in range(len(files)):
    imedian2[i] = np.nanmedian(image[i,200:,:])
    istd2[i] = np.nanstd(image[i,200:,:])
    #sets the median and std arrays to hold the median and std of each image

for i in range(len(image)):
    istand = image[i] - imedian2[i]
    bad1 = (istand > istd2[i]) * 1
    #check if 1 standard deviation above the median
    bad2 = (istand < -istd2[i]) * 1
    #check if 1 standard deviation below the median
    bad = bad1 + bad2
    #will be 1 if one standard deviation off (above or below), 0 otherwise
    bads += bad
#counts the number

#print(bads)
#print(bads[:,1:])
b = bads[:, 200:]
print(b)
pix = np.zeros((1024,824))
ctr = 0
for i in range(1024):
    for j in range(824):
        if b[i,j] >= 20:
            ctr += 1
            pix[i,j] = 1
            #print(i,j)
#checks number of images for which a pixel is in "bads"
#if  >20 times bad, sets the pixel's corresponding point in "pix" to 1
            
print(str(ctr/(1024 * 824)))
#gives ratio of flaged pixels to all pixels
# Out:
# [[ 8.  6.  5. ...  6. 10.  8.]
#  [10. 11.  5. ... 12. 11.  5.]
#  [10. 12. 10. ...  9.  4. 13.]
#  ...
#  [15.  9.  3. ...  4. 16.  5.]
#  [12.  7.  5. ... 10.  8. 13.]
#  [ 9. 11. 14. ... 10. 11. 18.]]
# 0.00751976827973301

# %% [markdown]
# The above array gives the number of times, for each pixel, it has been deemed "bad" in the list of 300 darks.

# %% [markdown]
# If we check pixels that have been bad at least once: 49.2% of pixels meet this criteria If we check pixels that have been bad at least twice: 18.5% of pixels meet this criteria If we check pixels that have been bad at least 3 times: 8.28% of pixels meet this criteria If we check pixels that have been bad at least 4 times: 5.21% of pixels meet this criteria ...

# %% [markdown]
# Following code makes list

# %%
pix3 = np.zeros((1024,824))
#makes 2D a zero array that will become our final list of pixels to smooth over
mask3 = np.zeros((len(files),1024,824))
#zero array that will become a stack of masks
for i in range(1024):
    for j in range(824):
        if pix[i,j] == 1:
        #checks if pixel has been flagged by first algorithm, ignore if not
        #this next series of if statements considers several different possible pixel locations, with the goal of setting a "sur"
        #"sur" is a 2D array that is basically the pixel values of the surronding area
            if i >= 5 and i < 1019:
                #all of these use a row value between 5 and 1019
                if j >= 5 and j < 819:
                    sur = image[:,i-5:i+5,200+j-5:200+j+5]
                    #these pixels are in places where we can easily check the surronding area
                elif j < 5:
                    sur = np.append(image[:,i-5:i+5,200:200+j], image[:,i-5:i+5,-10+j:])
                    #if in a colum <5, wraps around the side to fill in the rest of the neighborhood
                else:
                    sur = np.append(image[:,i-5:i+5,j:], image[:,i-5:i+5,200:210-1024+j])
                    #column in last 5, wraps around to fill in rest of neighborhood
            elif i < 5:
                #all of these are for a row value less than 5
                if j >= 5 and j < 819:
                    sur = np.append(image[:,:i,200+j-5:200+j+5], image[:,-10+i:,200+j-5:200+j+5])
                    #accaptable column value, only need to wrap around top-bottom (rows)
                elif j < 5:
                    sur = np.append(image[:,:i,200:200+j], image[:,-10+i:,-10+j:])
                    #in a corner, wraps around to fill in both dimensions
                else:
                    sur = np.append(image[:,:i,j:], image[:,-10+i:,200:210-1024+j])
                    #second corner
            else:
                #row values in the last 5
                if j >= 5 and j < 819:
                    sur = np.append(image[:,i:,200+j-5:200+j+5], image[:, :10-1024+i,200+j-5:200+j+5])
                    #accaptable column value, only need to wrap around top-bottom (rows)
                elif j < 5:
                    sur = np.append(image[:,i:,200:200+j], image[:, :10-1024+i,-10+j:])
                    #third corner, wrap around in both dimensions
                else:
                    sur = np.append(image[:,i:,j:], image[:, :10-1024+i,200:210-1024+j])
                    #fourth corner
            surmed = np.nanmedian(sur)
            #sets surmed to median value of the surronding area
            surstd = np.nanstd(sur)
            #sets surstd to standard deviation of surronding area
            pmed = np.nanmedian(image[:,i,200+j])
            #finds the median value of the pixel accross all 32 images
            pix3[i,j] = abs(surmed - pmed) > surstd

# %% [markdown]
# ## Making masks

# %%
# Make a median dark image from the image stack
dark = np.nanmedian(image, axis=0)
# make a bias file
bias = dark.copy()

# take a median row slice and smooth it
rowslice = np.median(bias, axis=0)
smooth_rowslice = signal.medfilt(rowslice, kernel_size=5)
smooth_rowslice = signal.savgol_filter(smooth_rowslice, window_length=101, polyorder=1)

# %%
#making initial mask
for i in range(1024):
    for j in range(824):          
            # sets to 1 if the median pixel value is more than one standard deviation away from the median of the surronding area
            if pix3[i,j] == 1:
                mask3[:,i,j] = image[:,i,200+j] - rowslice[200+j]
                #if pix3 is 1, sets the mask to be the value of the original image minus that value of the neighborhood median

# %%
#masking for pix3 

maskhelp2 = np.zeros((len(files),1024,200))
mask6 = np.append(maskhelp2,mask3, axis=2)

smoothed3 = image-mask6

# %% [markdown]
# DO NOT RUN

# %%
# # Display all the images in the stack.
# figx, figy = 20,20   # Use these to reveal fine detail in images.
figx, figy = 8,8   # Use these to get a quick look and save space.

for i in range(len(files)):
    plt.figure(figsize = (figx,figy))
    vmx= imedian[i] + madstd[i] * 3.0
    vmn = imedian[i] - madstd[i] * 3.0
#     grid()
    plt.title(files[i] + '   Median =' + str(imedian[i]) + '    mad_std =' + str(madstd[i]))
    plt.imshow(smoothed[i],'gray',interpolation = 'nearest',vmax=vmx,vmin=vmn)

# %% [markdown]
# ## creating and saving dead pixels fits

# %%
#creating a workable data format for our boolean 2D Array
hdumy = fits.PrimaryHDU(pix3)

#Turning Workable Object into a fits
outd = fits.HDUList([hdumy])

## Construct a name and 'save directory' for the dark-subtracted, flatfielded image.
outname = 'bad_pixels' + '(INSERT NUMBER OR OTHER THING!!!!! OR ITLL BREAK SOME STUFF) 5' + '.fits'
outpath = savepath
print('outpath =',outpath)
outf = os.path.join(outpath,outname)
print('outname =',outname)

# %%
## Now save the file (or not).
print(outf)
yes_or_no = input('Save file? Enter "y" or "n":')
if yes_or_no == 'y':
    outd.writeto(outf, overwrite = False)
    print( outname + ' has been saved.')
else:
    print( 'OK-- file was not saved.')

# outd.save(outf)

# %% [markdown]
# # Task 2 Creating Fits of Noisy Pixels

# %%
#In dah_functions2 but my imports are being weird so i did it.
def stackfits(whichpath,files):
    '''
    Make a stack of images, a list of headers from those images, and 1D arrays for medians and mad_stds.
    whichpath:   The path to the fits files.
    files:  A list of files.
    '''

    ## Load the header of the first file in the list "files".
    df = DataFits()                                                   # Create a DataPype DataFits io object.
    df.loadhead(os.path.join(whichpath,files[0]))                # Loads just the header of the first file.
    ## Make variables for the numbers of rows and columns.
    rows, cols = df.header['naxis2'], df.header['naxis1']
    print('rows =',rows,'   cols =',cols)

    image = np.zeros((len(files), rows,cols))  # 3D numpy array to hold the stack of images.
    imedian = np.zeros((len(files)))           # 1D numpy array to hold array medians.
    imad = np.zeros((len(files)))            # 1D numpy array to hold Median absolute deviations.

    headlist = []                              # Empty list to hold the headers.
    print('image.shape =', image.shape)

    for i in range(len(files)):

    # ########################################################################   
        # Use this code block if you want to work with DataFits objects
        df = DataFits() 
        df.load(os.path.join(whichpath,files[i]))
        image[i] = df.imageget() * 1.0            # Load image data into numpy arrays and convert to float.
        headlist.append(df.header)
        imedian[i] = np.nanmedian(image[i])
        imad[i] = mad_std(image[i],ignore_nan=True)
        print('')
        print(i, files[i])
    # #########################################################################

    #############################################################################
    #     # Use this code block if you want to use the standard astropy.io package.
    #     fitsfilename = os.path.join(datapath, files[i])    # Full path to a fitsfile.
    #     hdulist = fits.open(fitsfilename)                  # Open a fits file as an hdulist object.
    #     hdu0 = hdulist[0]                                  # Define a fits object as the 0th hdu in the fitsfile.
    #     image[i] = hdu0.data * 1.0                         # Define image in stack as float of data in the 0th hdu.
    #     headlist.append(hdu0.header)                       # Append the header of the fits object to the header list.
    #     print('')
    #     print(i,files[i])
    ###############################################################################   
    return image, headlist, rows, cols, imedian, imad

# %%
nbimage, nbheadlist, nbrows, nbcols, nbimedian, nbimad = stackfits(datapath,allfiles)

# %%
#This is very important

bstackarray = nbimage

# %%
#Analyze the variation of each pixel in the stack

bstackarray_std = np.std(bstackarray, axis=0)

bimg_global_std = np.median(bstackarray_std)

bnoisy_pixels = bstackarray_std > bimg_global_std*1.8

#we identified the pixels across the bias exposures whose values deviate from their respective means by 1.8 standard deviations
# this threshold was chosen based on visual comparisons with 1.7 standev and 1.9 standev

# %%
#Identify and list the pixels that exceed the noise threshold

## plt.imshow(noisy_pixels)

blocs = np.array(np.where(bnoisy_pixels == True))
nbpix_bias = np.zeros((1019,1019)) 
for i in range(1019): #1024
    for j in range(1019): #1024
        if bnoisy_pixels[i,j] == True and j > 5:
            nbpix_bias[i,j] = 1
            

# for i in range(locs.shape[1]):
#     print(locs[0,i],locs[1,i])
    
#this prints a list of noisy pixels

# %%
#Now we repeat the process for 020s
##This can be applied to any subset of raw fits images.
##In this example we used a single data set subdivided into exposure types

somefiles = [f for f in os.listdir(whichpath) if '.fit' in f and '_020s' in f and'stack' not in f]

somefiles = sorted(somefiles)       ## This is necessary on my Mac, may not be for others?


acceptlist = True             # True if you want to accept all the files in somefiles.
contiguous = True             # True if you want to accept a contiguous subset of somefiles.
startfile, endfile = 5,9      # The first and last files in a contiquous subset.
flist = [0,3,4,5,6,7,8]        # An explicit list of the files you want to accept.

n20image, n20headlist, n20rows, n20cols, n20imedian, n20imad = stackfits(datapath,somefiles)


n20stackarray = n20image

n20stackarray_std = np.std(n20stackarray, axis=0)

n20img_global_std = np.median(n20stackarray_std)

n20noisy_pixels = n20stackarray_std > n20img_global_std*1.8


n20locs = np.array(np.where(n20noisy_pixels == True))
npix_020s = np.zeros((1019,1019)) 
for i in range(1019): #1024
    for j in range(1019): #1024
        if n20noisy_pixels[i,j] == True and j > 5:
            npix_020s[i,j] = 1

# %%
#Now we repeat the process for 040s
##This can be applied to any subset of raw fits images.
##In this example we used a single data set subdivided into exposure types

somefiles = [f for f in os.listdir(whichpath) if '.fit' in f and '_040s' in f and'stack' not in f]

somefiles = sorted(somefiles)       ## This is necessary on my Mac, may not be for others?


acceptlist = True             # True if you want to accept all the files in somefiles.
contiguous = True             # True if you want to accept a contiguous subset of somefiles.
startfile, endfile = 5,9      # The first and last files in a contiquous subset.
flist = [0,3,4,5,6,7,8]        # An explicit list of the files you want to accept.

n40image, n40headlist, n40rows, n40cols, n40imedian, n40imad = stackfits(datapath,somefiles)


n40stackarray = n40image

n40stackarray_std = np.std(n40stackarray, axis=0)

n40img_global_std = np.median(n40stackarray_std)

n40noisy_pixels = n40stackarray_std > n40img_global_std*1.8


n40locs = np.array(np.where(n40noisy_pixels == True))
npix_040s = np.zeros((1019,1019)) 
for i in range(1019): #1024
    for j in range(1019): #1024
        if n40noisy_pixels[i,j] == True and j > 5:
            npix_040s[i,j] = 1

# %%
#Now we repeat the process for 100s
##This can be applied to any subset of raw fits images.
##In this example we used a single data set subdivided into exposure types

somefiles = [f for f in os.listdir(whichpath) if '.fit' in f and '_100s' in f and'stack' not in f]

somefiles = sorted(somefiles)       ## This is necessary on my Mac, may not be for others?


acceptlist = True             # True if you want to accept all the files in somefiles.
contiguous = True             # True if you want to accept a contiguous subset of somefiles.
startfile, endfile = 5,9      # The first and last files in a contiquous subset.
flist = [0,3,4,5,6,7,8]        # An explicit list of the files you want to accept.

n100image, n100headlist, n100rows, n100cols, n100imedian, n100imad = stackfits(datapath,somefiles)


n100stackarray = n100image

n100stackarray_std = np.std(n100stackarray, axis=0)

n100img_global_std = np.median(n100stackarray_std)

n100noisy_pixels = n100stackarray_std > n100img_global_std*1.8


n100locs = np.array(np.where(n100noisy_pixels == True))
npix_100s = np.zeros((1019,1019)) 
for i in range(1019): #1024
    for j in range(1019): #1024
        if n100noisy_pixels[i,j] == True and j > 5:
            npix_100s[i,j] = 1

# %%
#Now we repeat the process for 0180s
##This can be applied to any subset of raw fits images.
##In this example we used a single data set subdivided into exposure types

somefiles = [f for f in os.listdir(whichpath) if '.fit' in f and '_180s' in f and'stack' not in f]

somefiles = sorted(somefiles)       ## This is necessary on my Mac, may not be for others?


acceptlist = True             # True if you want to accept all the files in somefiles.
contiguous = True             # True if you want to accept a contiguous subset of somefiles.
startfile, endfile = 5,9      # The first and last files in a contiquous subset.
flist = [0,3,4,5,6,7,8]        # An explicit list of the files you want to accept.

n180image, n180headlist, n180rows, n180cols, n180imedian, n180imad = stackfits(datapath,somefiles)


n180stackarray = n180image

n180stackarray_std = np.std(n180stackarray, axis=0)

n180img_global_std = np.median(n180stackarray_std)

n180noisy_pixels = n180stackarray_std > n180img_global_std*1.8


n180locs = np.array(np.where(n180noisy_pixels == True))
npix_180s = np.zeros((1019,1019)) 
for i in range(1019): #1024
    for j in range(1019): #1024
        if n180noisy_pixels[i,j] == True and j > 5:
            npix_180s[i,j] = 1

# %%
#Stack the arrays of noisy pixels

dims = list(nbpix_bias.shape)
dims.append(5)
dims = [5,nbpix_bias.shape[0],nbpix_bias.shape[1]]
npixm = np.zeros(dims)
npixm[0,:,:]= nbpix_bias
npixm[1,:,:]= npix_020s
npixm[2,:,:]= npix_040s
npixm[3,:,:]= npix_100s
npixm[4,:,:]= npix_180s

# %%
#creating a workable data format for our boolean 2D Array
hdumy = fits.PrimaryHDU(npixm)

#Turning Workable Object into a fits
outd = fits.HDUList([hdumy])

## Construct a name and 'save directory' for the dark-subtracted, flatfielded image.
outname = 'noisy_pixels' + '(INSERT NUMBER OR OTHER THING!!!!! OR ITLL BREAK SOME STUFF) 1' + '.fits'
outpath = savepath
print('outpath =',outpath)
outf = os.path.join(outpath,outname)
print('outname =',outname)

# %%
## Now save the file (or not).
print(outf)
yes_or_no = input('Save file? Enter "y" or "n":')
if yes_or_no == 'y':
    outd.writeto(outf, overwrite = False)
    print( outname + ' has been saved.')
else:
    print( 'OK-- file was not saved.')

# outd.save(outf)
